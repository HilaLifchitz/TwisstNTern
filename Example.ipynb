# %%
import twisstntern
# Out:
# -7.77156117237610e-16
# 0.0
# d_lr = -0.033818557048939886
#
# g-test = 176.2621080957174
#
# g-test- p value= 0.0

# %% [markdown]
# # User Interface

# %%
granuality = "fine"
res=twisstntern.run_analysis("weights.csv",granuality)

# %%
res.head()
# Out:
#                     coord. (T1, T2, T3)  n_right  n_left       D-LR  \
# 0  [(0.0, 0.1), (0.0, 0.1), (0.9, 1.0)]      318      17 8.9851e-01
# 1  [(0.0, 0.1), (0.0, 0.1), (0.8, 0.9)]      133      44 5.0282e-01
# 2  [(0.0, 0.1), (0.1, 0.2), (0.8, 0.9)]       54      13 6.1194e-01
# 3  [(0.0, 0.1), (0.1, 0.2), (0.7, 0.8)]      104      54 3.1646e-01
# 4  [(0.0, 0.1), (0.2, 0.3), (0.7, 0.8)]       25      11 3.8889e-01
#
#       g-test  p-value(g-test)  index
# 0 3.2994e+02       0.0000e+00     45
# 1 4.6859e+01       7.6296e-12     44
# 2 2.6952e+01       2.0859e-07     43
# 3 1.6098e+01       6.0146e-05     42
# 4 5.5907e+00       1.8056e-02     41

# %%
twisstntern.run_basic_analysis("weights.csv")
# Out:
# d_lr = -0.033818557048939886
#
# g-test = 176.2621080957174
#
# g-test- p value= 0.0
# (74438, 79649, -0.033818557048939886, 176.2621080957174, 0.0)
