# %% [markdown]
# # Example

# %% [markdown]
# The python code named "twisstntern.py" should be in the directory from which you are working, along with the data set.

# %%
# we import the tiststern library
import twisstntern

# %% [markdown]
# # User Interface
# data_set: should be a csv file containt 3 columns in the csv- assuming first column is T1, second is T2, and third T3. <br>
# granuality: pick one of the following options: "coarse", "fine" or "superfine". The first corressponds to granuality of 0.25, the second 0.1 and the last 0.05.

# %%
granuality = "coarse"# coarse. fine super fine
name_of_data = "weights.csv" # a csv file containing 
res=twisstntern.run_analysis(name_of_data,granuality)

# %%
res.head()
# Out:
#                        coord. (T1, T2, T3)  n_right  n_left       D-LR  \
# 0  [(0.0, 0.05), (0.0, 0.05), (0.95, 1.0)]      208       4 9.6226e-01
# 1  [(0.0, 0.05), (0.0, 0.05), (0.9, 0.95)]       55       6 8.0328e-01
# 2  [(0.0, 0.05), (0.05, 0.1), (0.9, 0.95)]       21       2 8.2609e-01
# 3  [(0.0, 0.05), (0.05, 0.1), (0.85, 0.9)]       20       5 6.0000e-01
# 4  [(0.0, 0.05), (0.1, 0.15), (0.85, 0.9)]        5       1 6.6667e-01
#
#       g-test  p-value(g-test)  index
# 0 2.5421e+02       0.0000e+00    190
# 1 4.5345e+01       1.6520e-11    189
# 2 1.8295e+01       1.8925e-05    188
# 3 9.6372e+00       1.9067e-03    187
# 4 2.9110e+00       8.7976e-02    186

# %%
twisstntern.run_basic_analysis("weights.csv")
# Out:
# d_lr = -0.033818557048939886
#
# g-test = 176.2621080957174
#
# g-test- p value= 0.0
# (74438, 79649, -0.033818557048939886, 176.2621080957174, 0.0)
